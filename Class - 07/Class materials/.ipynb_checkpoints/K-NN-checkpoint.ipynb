# %% [markdown]
# # Tasks: 01 Manually implements K-NN using python

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Manually implements using K-NN Regression functions

# %%
data = {
    'age' : [21, 20, 22, 22, 23, 21, 25, 30, 31],
    'income' : [60, 55, 60, 61, 65, 62, 65, 70, 68]
}

age = np.array([21, 20, 22, 22, 23, 21, 25, 30, 31])
income = np.array([60, 55, 60, 61, 65, 62, 65, 70, 68])

def euclidean_distance(age1, age2):
    return np.sqrt((age1 - age2) ** 2)


def knn_regression(age, income, query_age, k):
    distances = []  

    
    for i in range(len(age)):
        dist = euclidean_distance(age[i], query_age)  
        distances.append((dist, income[i])) 

    distances = sorted(distances)
    nearest_neighbors = distances[:k]   # nearest neighbors search 
    avg_income = np.mean([neighbor[1] for neighbor in nearest_neighbors])
    
    return avg_income


query_age = int(input("Enter your age: "))
k = int(input("Enter the number of neighbors: "))

pred_income = knn_regression(age, income, query_age, k)
print(f"Predicted income {query_age}: {pred_income}")
# Out:
# Enter your age:  22
# Enter the number of neighbors:  3
# Predicted income 22: 60.333333333333336

# %% [markdown]
# # Manually implements using K-NN classifier functions

# %%
data = {
    'age' : [21, 20, 22, 22, 23, 21, 25, 30, 31],
    'income' : [60, 55, 60, 61, 65, 62, 65, 70, 68]
}

age = np.array([21, 20, 22, 22, 23, 21, 25, 30, 31])
income = np.array([60, 55, 60, 61, 65, 62, 65, 70, 68])

def euclidean_distance(age1, age2):
    return np.sqrt((age1 - age2) ** 2)


def knn_classifier(age, income, query_age, k):
    distances = []  

    
    for i in range(len(age)):
        dist = euclidean_distance(age[i], query_age)  
        distances.append((dist, income[i])) 

    distances = sorted(distances)
    nearest_neighbors = distances[:k]   # nearest neighbors search 
    avg_income = np.mean([neighbor[1] for neighbor in nearest_neighbors])
    
    return avg_income


query_age = int(input("Enter your age: "))
k = int(input("Enter the number of neighbors: "))

pred_income = knn_regression(age, income, query_age, k)
print(f"Predicted income {query_age}: {pred_income}")
# Out:
# Enter your age:  22
# Enter the number of neighbors:  3
# Predicted income 22: 60.333333333333336

# %% [markdown]
# # Final Task: Generate an Excel spreadsheet for a provided dataset.

# %%
df = pd.read_csv('income_prediction_with_ege.csv')
df.head()
# Out:
#    age  income(k)
# 0   21         60
# 1   20         55
# 2   22         60
# 3   22         61
# 4   23         65

# %%
df.tail()
# Out:
#    age  income(k)
# 4   23         65
# 5   21         62
# 6   25         65
# 7   30         70
# 8   31         68

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        9 non-null      int64
#  1   income(k)  9 non-null      int64
# dtypes: int64(2)
# memory usage: 276.0 bytes

# %%
df.describe()
# Out:
#              age  income(k)
# count   9.000000   9.000000
# mean   23.888889  62.888889
# std     4.013865   4.594683
# min    20.000000  55.000000
# 25%    21.000000  60.000000
# 50%    22.000000  62.000000
# 75%    25.000000  65.000000
# max    31.000000  70.000000

# %%
df.corr()
# Out:
#                 age  income(k)
# age        1.000000   0.887145
# income(k)  0.887145   1.000000

# %%
df.shape
# Out:
# (9, 2)

# %%
df.isnull().sum()
# Out:
# age          0
# income(k)    0
# dtype: int64

# %%
x = df[['age']]
y = df['income(k)']

# %%
x.head()
# Out:
#    age
# 0   21
# 1   20
# 2   22
# 3   22
# 4   23

# %%
y.head()
# Out:
# 0    60
# 1    55
# 2    60
# 3    61
# 4    65
# Name: income(k), dtype: int64

# %% [markdown]
# # Least Squared Linear Regression

# %%
reg = LinearRegression()

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
slope = reg.coef_
print(f"Slope (M): {slope}")
# Out:
# Slope (M): [1.01551724]

# %%
intercept = reg.intercept_
print(f"Intercept (C): {intercept}")
# Out:
# Intercept (C): 38.629310344827594

# %%
df['Predicted income(k)'] = reg.predict(x)   # Predict prices using the regression model
df
# Out:
#    age  income(k)  Predicted income(k)
# 0   21         60            59.955172
# 1   20         55            58.939655
# 2   22         60            60.970690
# 3   22         61            60.970690
# 4   23         65            61.986207
# 5   21         62            59.955172
# 6   25         65            64.017241
# 7   30         70            69.094828
# 8   31         68            70.110345

# %%
plt.scatter(df['age'], df['income(k)'], color='blue', label='Actual Income(k)')
plt.plot(df['age'], df['Predicted income(k)'], color='red', label='Predicted Income(k)')


plt.xlabel('Age')
plt.ylabel('Income(k)')
plt.title('K-NN Regression: Age vs Income(k)')
plt.legend()
plt.show()

# %%
reg.predict([[22]])
# Out:
# array([60.97068966])

# %%
df['Residuals'] = df['income(k)'] - df['Predicted income(k)']
df
# Out:
#    age  income(k)  Predicted income(k)  Residuals
# 0   21         60            59.955172   0.044828
# 1   20         55            58.939655  -3.939655
# 2   22         60            60.970690  -0.970690
# 3   22         61            60.970690   0.029310
# 4   23         65            61.986207   3.013793
# 5   21         62            59.955172   2.044828
# 6   25         65            64.017241   0.982759
# 7   30         70            69.094828   0.905172
# 8   31         68            70.110345  -2.110345

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

predict_price = reg.predict(x)

mse = mean_squared_error(y, predict_price) 
mae = mean_absolute_error(y, predict_price)  

print(f"MSE : {mse}")
print(f"MAE : {mae}")
# Out:
# MSE : 3.996551724137932
# MAE : 1.5601532567049818

# %% [markdown]
# # KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=3)

# %%
knn.fit(x, y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
predicted_income = knn.predict([[22]])
print(f'Predicted Income for age 22: {predicted_income[0]}')
# Out:
# Predicted Income for age 22: 60.333333333333336

# %% [markdown]
# # KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
predicted_income = knn.predict([[22]])
print(f'Predicted Income for age 22: {predicted_income[0]}')
# Out:
# Predicted Income for age 22: 60

# %% [markdown]
# # Compare the predicted outcomes of the KNN algorithm with Linear Regression results.

# %%
print(f"\n🔄 Compare predicted K-NN and Linear regression")
pred_income = reg.predict([[22]])
print(f"\n1.Predicted income for Linear Regression: {pred_income}")


predicted_income = knn.predict([[22]])
print(f'\n2.Predicted Income for K-NN: {predicted_income[0]}')
# Out:
# 🔄 Compare predicted K-NN and Linear regression
#
# 1.Predicted income for Linear Regression: [60.97068966]
#
# 2.Predicted Income for K-NN: 60
